# %% [markdown]
# # Rock and Mineral Clubs
#
# Scrape all of the rock and mineral clubs listed at https://rocktumbler.com/blog/rock-and-mineral-clubs/ (but don't just cut and paste!)
#
# Save a CSV called `rock-clubs.csv` with the name of the club, their URL, and the city they're located in.
#
# **Bonus**: Add a column for the state. There are a few ways to do this, but knowing that `element.parent` goes 'up' one element might be helpful.
#
# * _**Hint:** The name of the club and the city are both inside of td elements, and they aren't distinguishable by class. Instead you'll just want to ask for all of the tds and then just ask for the text from the first or second one._
# * _**Hint:** If you use BeautifulSoup, you can select elements by attributes other than class or id - instead of `doc.find_all({'class': 'cat'})` you can do things like `doc.find_all({'other_attribute': 'blah'})` (sorry for the awful example)._
# * _**Hint:** If you love `pd.read_html` you might also be interested in `pd.concat` and potentially `list()`. But you'll have to clean a little more!_

# %%
#Importing necessary libraries

import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import re

# %%
url = "https://rocktumbler.com/blog/rock-and-mineral-clubs/"
r = requests.get(url).content

soup_doc = BeautifulSoup(r, "html.parser")
print(soup_doc.prettify())

# %%
sections = soup_doc.find_all('section')[1:]
sections[0]

# %%
#Creating list of dictionaries 'rock_list'

rock_list = []


for i in range(0, len(sections)-2, 1):
 
    #extract title
    trs = sections[i].find_all('tr')
    state = trs[0].find('h3')
    
    for title in trs[1:]:
        rocks ={}
        rocks['title'] = title.find('a').text
        rocks['state'] = state.text.replace("Rock and Mineral Clubs", "").strip(" ")
        rocks['link'] = title.a['href']
        rocks['city'] = title.find_all('td')[1].text
        rock_list.append(rocks)
        
rock_list
# Out:
# [{'title': 'Alabama Mineral & Lapidary Society',
#   'state': 'Alabama',
#   'link': 'http://www.lapidaryclub.com/',
#   'city': 'Birmingham'},
#  {'title': 'Dothan Gem & Mineral Club',
#   'state': 'Alabama',
#   'link': 'http://www.wiregrassrockhounds.com/',
#   'city': 'Dothan'},
#  {'title': 'Huntsville Gem and Mineral Society',
#   'state': 'Alabama',
#   'link': 'http://huntsvillegms.org/',
#   'city': 'Huntsville'},
#  {'title': 'Mobile Rock & Gem Society',
#   'state': 'Alabama',
#   'link': 'http://www.mobilerockandgem.com/',
#   'city': 'Mobile'},
#  {'title': 'Montgomery Gem & Mineral Society',
#   'state': 'Alabama',
#   'link': 'http://montgomerygemandmineralsociety.com/mgms/',
#   'city': 'Montgomery'},
#  {'title': 'Chugach Gem & Mineral Society',
#   'state': 'Alaska',
#   'link': 'http://www.chugachgemandmineralsociety.com/',
#   'city': 'Anchorage'},
#  {'title': 'Mat-Su Rock and Mineral Club',
#   'state': 'Alaska',
#   'link': 'http://matsurockclub.com/',
#   'city': 'Palmer'},
#  {'title': 'Apache Junction Rock and Gem Club',
#   'state': 'Arizona',
#   'link': 'http://www.ajrockclub.com/',
#   'city': 'Apache Junction'},
#  {'title': 'Black Canyon City Rock Club',
#   'state': 'Arizona',
#   'link': 'http://www.bccrockclub.mysite.com/',
#   'city': 'Black Canyon City'},
#  {'title': 'Daisy Mountain Rock & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.dmrmc.com/',
#   'city': 'Anthem'},
#  {'title': 'Gila County Gem & Mineral Society',
#   'state': 'Arizona',
#   'link': 'http://gilagem.org/',
#   'city': 'Miami'},
#  {'title': 'Huachuca Mineral and Gem Club',
#   'state': 'Arizona',
#   'link': 'http://www.huachucamineralandgemclub.info/',
#   'city': 'Sierra Vista'},
#  {'title': 'Lake Havasu Gem & Mineral Society',
#   'state': 'Arizona',
#   'link': 'http://www.lakehavasugms.org/',
#   'city': 'Lake Havasu City'},
#  {'title': 'Mineralogical Society of Arizona',
#   'state': 'Arizona',
#   'link': 'http://www.msaaz.org/',
#   'city': 'Scottsdale'},
#  {'title': 'Mingus Gem & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.mingusclub.org/',
#   'city': 'Cottonwood'},
#  {'title': 'Mohave County Gemstoners',
#   'state': 'Arizona',
#   'link': 'http://www.gemstoners.org/',
#   'city': 'Kingman'},
#  {'title': 'Old Pueblo Lapidary Club',
#   'state': 'Arizona',
#   'link': 'http://www.lapidaryclub.org/',
#   'city': 'Tucson'},
#  {'title': 'Pinal Gem and Mineral Society',
#   'state': 'Arizona',
#   'link': 'https://www.pinalgeologymuseum.org/index.php/pinal-gem-mineral-society/about-pgms',
#   'city': 'Coolidge'},
#  {'title': 'Prescott Gem & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.prescottgemmineral.org/',
#   'city': 'Prescott Valley'},
#  {'title': 'Quartzsite Roadrunners Gem & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.qrgmc.org/',
#   'city': 'Quartzsite'},
#  {'title': 'Rockhounds West',
#   'state': 'Arizona',
#   'link': 'http://rockhounds.scwclubs.com/',
#   'city': 'Phoenix'},
#  {'title': 'Sedona Gem & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.sedonagemandmineral.org/',
#   'city': 'Sedona'},
#  {'title': 'Silvery Colorado River Rock Club',
#   'state': 'Arizona',
#   'link': 'http://scrrc.blogspot.com/',
#   'city': 'Bullhead City'},
#  {'title': 'Sunsites Gem and Mineral Club',
#   'state': 'Arizona',
#   'link': 'https://sites.google.com/site/cochisecountyrock/',
#   'city': 'Pearce'},
#  {'title': 'Tucson Gem and Mineral Society',
#   'state': 'Arizona',
#   'link': 'http://www.tgms.org/',
#   'city': 'Tucson'},
#  {'title': 'Verde River Rockhounds',
#   'state': 'Arizona',
#   'link': 'http://www.verderiverrockhounds.com/',
#   'city': 'Cottonwood'},
#  {'title': 'West Valley Rock & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://www.westvalleyrockandmineralclub.com/',
#   'city': 'Buckeye'},
#  {'title': 'White Mountain Gem & Mineral Club',
#   'state': 'Arizona',
#   'link': 'http://whitemountain-azrockclub.org/',
#   'city': 'Show Low'},
#  {'title': 'Wickenburg Gem and Mineral Society',
#   'state': 'Arizona',
#   'link': 'http://www.wickenburggms.org/',
#   'city': 'Wickenburg'},
#  {'title': 'Central Arkansas Gem, Mineral and Geology Society',
#   'state': 'Arkansas',
#   'link': 'http://www.centralarrockhound.org/',
#   'city': 'Little Rock'},
#  {'title': 'Northwest Arkansas Gem & Mineral Society',
#   'state': 'Arkansas',
#   'link': 'http://www.nwarockhounds.org/',
#   'city': 'Siloam Springs'},
#  {'title': 'Ozark Earth Science Gem, Mineral & Fossil Club',
#   'state': 'Arkansas',
#   'link': 'https://www.ozarkearthscience.com/',
#   'city': 'Mountain Home'},
#  {'title': 'Amador County Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.amadorgemandmineral.org/',
#   'city': 'Sutter Creek'},
#  {'title': 'American Opal Society',
#   'state': 'California',
#   'link': 'http://www.opalsociety.org/',
#   'city': 'Anaheim'},
#  {'title': 'Antelope Valley Gem and Mineral Club',
#   'state': 'California',
#   'link': 'http://avgem.weebly.com/',
#   'city': 'Lancaster'},
#  {'title': 'Antioch Lapidary Club',
#   'state': 'California',
#   'link': 'http://www.antiochlapidaryclub.com/',
#   'city': 'Antioch'},
#  {'title': 'Borrego Rock and Gem Club',
#   'state': 'California',
#   'link': 'http://www.abdnha.org/bragclub.html',
#   'city': 'Borrego Springs'},
#  {'title': 'Calaveras Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.calaverasgemandmineral.org/',
#   'city': 'Angels Camp'},
#  {'title': 'Carmel Valley Gem and Mineral Society',
#   'state': 'California',
#   'link': 'http://www.cvgms.rocks/',
#   'city': 'Pacific Grove'},
#  {'title': 'Central Coast Treasure Hunters Association',
#   'state': 'California',
#   'link': 'http://www.cctha.org/',
#   'city': 'San Luis Obispo'},
#  {'title': 'Coalinga Rockhound Society',
#   'state': 'California',
#   'link': 'https://sites.google.com/site/coalingarockhounds/',
#   'city': 'Coalinga'},
#  {'title': 'Conejo Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://www.cgamc.org/',
#   'city': 'Thousand Oaks'},
#  {'title': 'Contra Costa Mineral & Gem Society',
#   'state': 'California',
#   'link': 'http://www.ccmgs.org/',
#   'city': 'Concord'},
#  {'title': 'The Culver City Rock and Mineral Club',
#   'state': 'California',
#   'link': 'http://culvercityrocks.org/',
#   'city': 'Culver City'},
#  {'title': 'Del Air Rockhounds Club',
#   'state': 'California',
#   'link': 'http://delairrockhounds.blogspot.com/',
#   'city': 'Northridge'},
#  {'title': 'Delvers Gem & Mineral Society',
#   'state': 'California',
#   'link': 'https://delversgemclub.wordpress.com/',
#   'city': 'Bellflower'},
#  {'title': 'El Cajon Valley Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.ecvgms.org/',
#   'city': 'El Cajon'},
#  {'title': 'El Dorado County Mineral and Gem Society',
#   'state': 'California',
#   'link': 'http://www.eldoradomineralandgem.org/',
#   'city': 'Placerville'},
#  {'title': 'Faceters Guild of Southern California',
#   'state': 'California',
#   'link': 'http://www.fgosc.com/',
#   'city': 'Buena Park'},
#  {'title': 'Fallbrook Gem and Mineral Society, Inc.',
#   'state': 'California',
#   'link': 'http://www.fgms.org/FGMS/Home.html',
#   'city': 'Fallbrook'},
#  {'title': 'Feather River Lapidary & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.featherriverrocks.org/',
#   'city': 'Oroville'},
#  {'title': 'First Class Miners',
#   'state': 'California',
#   'link': 'http://www.firstclassminers.org/',
#   'city': 'Yucca Valley'},
#  {'title': 'Fossils for Fun Society, Inc.',
#   'state': 'California',
#   'link': 'https://www.facebook.com/The-Fossils-for-Fun-Society-994879667246272/',
#   'city': 'North Highlands'},
#  {'title': 'Fresno Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://fgms.us/',
#   'city': 'Fresno'},
#  {'title': 'Gold Country Treasure Seekers',
#   'state': 'California',
#   'link': 'https://goldcountrytreasureseekers.shutterfly.com/',
#   'city': 'Placerville'},
#  {'title': 'Hi-Desert Rockhounds of Morongo Valley',
#   'state': 'California',
#   'link': 'http://www.hi-desertrockhounds.org/',
#   'city': 'Yucca Valley'},
#  {'title': 'Indian Wells Valley Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://indianwells.weebly.com/',
#   'city': 'Ridgecrest'},
#  {'title': 'Kern County Mineral Society',
#   'state': 'California',
#   'link': 'http://kerncountymineralsociety.org/',
#   'city': 'Bakersfield'},
#  {'title': 'Lemoore Gem and Mineral Club',
#   'state': 'California',
#   'link': 'https://www.facebook.com/Lemoore-Gem-and-Mineral-Club-706220872829687/',
#   'city': 'Lemoore'},
#  {'title': 'Livermore Valley Lithophiles',
#   'state': 'California',
#   'link': 'http://www.lithophiles.com/',
#   'city': 'Livermore'},
#  {'title': 'Line Pine Gem & Mieral Society',
#   'state': 'California',
#   'link': 'http://lpgms.org/',
#   'city': 'Lone Pine'},
#  {'title': 'Mariposa Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://mariposagmc.org/',
#   'city': 'Mariposa'},
#  {'title': 'Mineral & Gem Society of Castro Valley',
#   'state': 'California',
#   'link': 'http://www.mgscv.org/',
#   'city': 'Hayward'},
#  {'title': 'Mineralogical Society of Southern California',
#   'state': 'California',
#   'link': 'http://www.mineralsocal.org/',
#   'city': 'Pasadena'},
#  {'title': 'Mojave Desert Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.mdgms.net/',
#   'city': 'Barstow'},
#  {'title': 'Monrovia Rock Hounds Inc.',
#   'state': 'California',
#   'link': 'http://www.moroks.com/',
#   'city': 'Monrovia'},
#  {'title': 'Mother Lode Mineral Society',
#   'state': 'California',
#   'link': 'http://www.motherlodemineralsociety.com/',
#   'city': 'Modesto'},
#  {'title': 'Needles Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://needlesgemmineralclub.blogspot.com/',
#   'city': 'Mohave Valley'},
#  {'title': 'Nevada County Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.ncgms.org/',
#   'city': 'Grass Valley'},
#  {'title': 'Northern California Geological Society',
#   'state': 'California',
#   'link': 'http://www.ncgeolsoc.org/',
#   'city': 'Orinda'},
#  {'title': 'North Orange County Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.nocgms.com/',
#   'city': 'La Habra'},
#  {'title': 'Orange Belt Mineralogical Society',
#   'state': 'California',
#   'link': 'http://obmsrocks.yolasite.com/',
#   'city': 'San Bernardino'},
#  {'title': 'Orcutt Mineral Society',
#   'state': 'California',
#   'link': 'http://www.omsinc.org/',
#   'city': 'Santa Maria'},
#  {'title': 'Oxnard Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://oxnardgem.com/home/',
#   'city': 'Oxnard'},
#  {'title': 'Palmdale Gem & Mineral Club',
#   'state': 'California',
#   'link': 'https://www.facebook.com/palmdalegemandmineralclub/',
#   'city': 'Palmdale'},
#  {'title': 'Palomar Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://palomargem.org/',
#   'city': 'Escondido'},
#  {'title': 'Palos Verdes Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.palos-verdes-gem-and-mineral-society.org/',
#   'city': 'Rolling Hills Estates'},
#  {'title': 'Paradise Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://www.paradisegem.org/',
#   'city': 'Paradise'},
#  {'title': 'Pasadena Lapidary Society',
#   'state': 'California',
#   'link': 'http://www.pasadenalapidarysociety.org/',
#   'city': 'Pasadena'},
#  {'title': 'Peninsula Gem & Geology Society, Inc.',
#   'state': 'California',
#   'link': 'http://pggs.org/',
#   'city': 'Los Altos'},
#  {'title': 'Roseville Rock Rollers',
#   'state': 'California',
#   'link': 'http://www.rockrollers.com/',
#   'city': 'Roseville'},
#  {'title': 'Route 66 Gold Miners Inc',
#   'state': 'California',
#   'link': 'http://www.route66goldminers.org/',
#   'city': 'Brea'},
#  {'title': 'Sacramento Mineral Society',
#   'state': 'California',
#   'link': 'http://www.sacramentomineralsociety.org/',
#   'city': 'Sacramento'},
#  {'title': 'Sacramento Valley Detecting Buffs',
#   'state': 'California',
#   'link': 'http://www.sacramentovalleydetectingbuffs.com/',
#   'city': 'North Highlands'},
#  {'title': 'Salinas Valley Rock and Gem Club',
#   'state': 'California',
#   'link': 'https://salinasrockandgem.pagecloud.com/',
#   'city': 'Salinas'},
#  {'title': 'San Diego Gem and Mineral Society',
#   'state': 'California',
#   'link': 'http://www.sdmg.org/',
#   'city': 'San Diego'},
#  {'title': 'San Diego Lapidary Society',
#   'state': 'California',
#   'link': 'http://sandiegolapidarysociety.org/',
#   'city': 'San Diego'},
#  {'title': 'San Francisco Gem and Mineral Society, Inc.',
#   'state': 'California',
#   'link': 'http://www.sfgms.org/',
#   'city': 'San Francisco'},
#  {'title': 'San Joaquin Valley Lapidary Society',
#   'state': 'California',
#   'link': 'http://sjvls.blogspot.com/',
#   'city': 'Bakersfield'},
#  {'title': 'San Luis Obispo Gem & Mineral Club',
#   'state': 'California',
#   'link': 'http://www.slogem.org/',
#   'city': 'San Luis Obispo'},
#  {'title': 'Santa Ana Rock & Mineral Club, Inc.',
#   'state': 'California',
#   'link': 'http://www.sarmclub.org/',
#   'city': 'Santa Ana'},
#  {'title': 'Santa Clara Valley Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.scvgms.org/',
#   'city': 'San Jose'},
#  {'title': 'Santa Cruz Mineral and Gem Society',
#   'state': 'California',
#   'link': 'https://www.facebook.com/scmgs/',
#   'city': 'Santa Cruz'},
#  {'title': 'Santa Lucia Rockhounds',
#   'state': 'California',
#   'link': 'http://www.slrockhounds.org/',
#   'city': 'Paso Robles'},
#  {'title': 'Santa Rosa Mineral And Gem Society, Inc.',
#   'state': 'California',
#   'link': 'http://www.srmgs.org/',
#   'city': 'Santa Rosa'},
#  {'title': 'Searchers Gem and Mineral Society',
#   'state': 'California',
#   'link': 'https://www.searchersrocks.org/',
#   'city': 'Anaheim'},
#  {'title': 'Searles Lake Gem and Mineral Society, Inc.',
#   'state': 'California',
#   'link': 'http://www1.iwvisp.com/tronagemclub/',
#   'city': 'Trona'},
#  {'title': 'Sequoia Gem and Mineral Society',
#   'state': 'California',
#   'link': 'http://www.sequoiagemandmineralsociety.org/',
#   'city': 'Redwood City'},
#  {'title': 'Shadow Mountain Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.shadowmountaingemmineral.org/',
#   'city': 'Palm Springs'},
#  {'title': 'Shasta Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.shastagemandmineral.com/',
#   'city': 'Redding'},
#  {'title': 'Sierra Pelona Rock Club',
#   'state': 'California',
#   'link': 'http://www.sierrapelona.com/',
#   'city': 'Newhall'},
#  {'title': 'South Bay Lapidary & Mineral Society',
#   'state': 'California',
#   'link': 'https://southbaylapidaryandmineralsociety.com/',
#   'city': 'Torrance'},
#  {'title': 'South Orange County Gem & Mineral Society',
#   'state': 'California',
#   'link': 'https://www.facebook.com/South-Orange-County-Gem-Mineral-Society-255366124502612/',
#   'city': 'San Clemente'},
#  {'title': 'Southern California Paleontological Society',
#   'state': 'California',
#   'link': 'http://socalpaleo.com/',
#   'city': 'Los Angeles'},
#  {'title': 'Stockton Lapidary & Mineral Club',
#   'state': 'California',
#   'link': 'http://www.stocktonlapidary.com/',
#   'city': 'Stockton'},
#  {'title': 'Sutter Buttes Gem & Mineral Society',
#   'state': 'California',
#   'link': 'https://sutterbuttesgemmin.org/',
#   'city': 'Marysville'},
#  {'title': 'Tehachapi Valley Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.tvgms.org/',
#   'city': 'Tehachapi'},
#  {'title': 'Tule Gem and Mineral Society',
#   'state': 'California',
#   'link': 'http://www.tulegem.com/',
#   'city': 'Farmersville'},
#  {'title': 'Vallejo Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.vjgems.org/',
#   'city': 'Vallejo'},
#  {'title': 'Valley Prospectors, Inc.',
#   'state': 'California',
#   'link': 'https://www.valleyprospectors.com/',
#   'city': 'San Bernardino'},
#  {'title': 'Ventura Gem & Mineral Society, Inc',
#   'state': 'California',
#   'link': 'http://vgms.org/',
#   'city': 'Ventura'},
#  {'title': 'Victor Valley Gem and Mineral Club',
#   'state': 'California',
#   'link': 'http://www.vvgmc.org/',
#   'city': 'Victorville'},
#  {'title': 'Vista Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.vistarocks.org/',
#   'city': 'Vista'},
#  {'title': 'West Coast Prospectors & Treasure Hunters Association',
#   'state': 'California',
#   'link': 'http://westcoasters.org/',
#   'city': 'Garden Grove'},
#  {'title': 'West End Prospectors Corporation',
#   'state': 'California',
#   'link': 'http://www.wepcgold.com',
#   'city': 'Norco'},
#  {'title': 'Whittier Gem and Mineral Society, Inc.',
#   'state': 'California',
#   'link': 'http://wgmsca.com/index.html',
#   'city': 'Whittier'},
#  {'title': 'Woodland Hills Rock Chippers, Inc.',
#   'state': 'California',
#   'link': 'http://www.rockchippers.org/',
#   'city': 'San Fernando Valley'},
#  {'title': 'Yucaipa Valley Gem & Mineral Society',
#   'state': 'California',
#   'link': 'http://www.yvgms.org/wiki/',
#   'city': 'Yucaipa'},
#  {'title': 'Canon City Geology Club',
#   'state': 'Colorado',
#   'link': 'http://www.canoncitygeologyclub.com/',
#   'city': 'Canon City'},
#  {'title': 'Colorado Gold Camp',
#   'state': 'Colorado',
#   'link': 'http://coloradogoldcamp.com/',
#   'city': 'Frisco'},
#  {'title': 'Colorado Mineral Society',
#   'state': 'Colorado',
#   'link': 'http://www.coloradomineralsociety.org/',
#   'city': 'Lakewood'},
#  {'title': 'Colorado Prospector',
#   'state': 'Colorado',
#   'link': 'http://www.coloradoprospector.com/',
#   'city': 'Alamosa'},
#  {'title': 'Colorado Springs Mineral Society',
#   'state': 'Colorado',
#   'link': 'http://www.csms1936.com/',
#   'city': 'Colorado Springs'},
#  {'title': 'Columbine Gem and Mineral Society',
#   'state': 'Colorado',
#   'link': 'http://rockaholics.org/',
#   'city': 'Salida'},
#  {'title': 'Denver Gem and Mineral Guild',
#   'state': 'Colorado',
#   'link': 'http://denvergem.org/index.html',
#   'city': 'Denver'},
#  {'title': 'Flatirons Mineral Club',
#   'state': 'Colorado',
#   'link': 'http://flatironsmineralclub.org/',
#   'city': 'Boulder'},
#  {'title': 'Fort Collins Rockhounds',
#   'state': 'Colorado',
#   'link': 'http://www.fortcollinsrockhounds.org/',
#   'city': 'Fort Collins'},
#  {'title': 'Four Corners Gem & Mineral Club',
#   'state': 'Colorado',
#   'link': 'http://www.durangorocks.org/',
#   'city': 'Durango'},
#  {'title': 'Friends of Mineralogy - Colorado Chapter ',
#   'state': 'Colorado',
#   'link': 'http://friendsofmineralogycolorado.org/',
#   'city': 'Denver'},
#  {'title': 'Grand Junction Gem & Mineral Club',
#   'state': 'Colorado',
#   'link': 'http://www.grandjunctionrockclub.org/',
#   'city': 'Grand Junction'},
#  {'title': 'Lake George Gem & Mineral club',
#   'state': 'Colorado',
#   'link': 'http://www.lggmclub.org/',
#   'city': 'Lake George'},
#  {'title': 'Littleton Gem and Mineral Club, Inc.',
#   'state': 'Colorado',
#   'link': 'http://littletongemandmineralclub.com/',
#   'city': 'Littleton'},
#  {'title': 'Mile High Rock and Mineral Society',
#   'state': 'Colorado',
#   'link': 'http://www.milehirams.com/',
#   'city': 'Arvada'},
#  {'title': 'North Jeffco Gem & Mineral Club',
#   'state': 'Colorado',
#   'link': 'http://www.peaktopeak.com/njeffco/index.php',
#   'city': 'Arvada'},
#  {'title': 'Pueblo Rockhounds',
#   'state': 'Colorado',
#   'link': 'http://www.pueblorockhounds.org/',
#   'city': 'Pueblo'},
#  {'title': 'Western Interior Paleontological Society',
#   'state': 'Colorado',
#   'link': 'http://www.westernpaleo.org/',
#   'city': 'Denver'},
#  {'title': 'Bristol Gem & Mineral Club',
#   'state': 'Connecticut',
#   'link': 'http://bristolgem.org/',
#   'city': 'Bristol'},
#  {'title': 'Danbury Mineralogical Society',
#   'state': 'Connecticut',
#   'link': 'http://danburymineralogicalsociety.weebly.com/',
#   'city': 'Danbury'},
#  {'title': 'Lapidary and Mineral Society of Central Connecticut',
#   'state': 'Connecticut',
#   'link': 'http://www.lmscc.org/',
#   'city': 'Meriden'},
#  {'title': 'New Haven Mineral Club',
#   'state': 'Connecticut',
#   'link': 'http://www.newhavenmineralclub.org/',
#   'city': 'New Haven'},
#  {'title': 'Stamford Mineralogical Society',
#   'state': 'Connecticut',
#   'link': 'http://www.stamfordmineralsociety.org/',
#   'city': 'Stamford'},
#  {'title': 'Delaware Mineralogical Society, Inc.',
#   'state': 'Delaware',
#   'link': 'http://www.delminsociety.net/',
#   'city': 'Wilmington'},
#  {'title': 'Canaveral Mineral & Gem Society',
#   'state': 'Florida',
#   'link': 'http://www.canaveral-mgs.com/',
#   'city': 'Melbourne'},
#  {'title': 'Central Brevard Rock and Gem Club',
#   'state': 'Florida',
#   'link': 'http://www.centralbrevardgems.org/',
#   'city': 'Merritt Island'},
#  {'title': 'Central Florida Mineral and Gem Society',
#   'state': 'Florida',
#   'link': 'http://www.cfmgs.org/',
#   'city': 'Winter Park'},
#  {'title': 'Florida Fossil Hunters',
#   'state': 'Florida',
#   'link': 'http://floridafossilhunters.com/',
#   'city': 'Orlando'},
#  {'title': 'Florida Gold Coast Gem & Mineral Society',
#   'state': 'Florida',
#   'link': 'http://fgcgms.com/main/',
#   'city': 'Hollywood'},
#  {'title': 'Fossil Club of Lee County',
#   'state': 'Florida',
#   'link': 'http://www.fcolc.com/',
#   'city': 'Ft. Myers'},
#  {'title': 'Gainesville Gem & Mineral Society',
#   'state': 'Florida',
#   'link': 'http://gainesvillegms.weebly.com/',
#   'city': 'Gainesville'},
#  {'title': 'Gem and Mineral Society of the Palm Beaches',
#   'state': 'Florida',
#   'link': 'http://www.gemandmineralsociety.org/',
#   'city': 'West Palm Beach'},
#  {'title': 'Imperial Bone Valley Gem, Mineral, & Fossil Society',
#   'state': 'Florida',
#   'link': 'http://www.bonevalley.net/',
#   'city': 'Lakeland'},
#  {'title': 'Jacksonville Gem and Mineral Society, Inc.',
#   'state': 'Florida',
#   'link': 'http://www.jaxgemandmineral.org/',
#   'city': 'Jacksonville'},
#  {'title': 'Miami Mineralogical and Lapidary Guild, Inc.',
#   'state': 'Florida',
#   'link': 'http://www.mmlg-inc.org/',
#   'city': 'Miami'},
#  {'title': 'Playground Gem and Mineral Society',
#   'state': 'Florida',
#   'link': 'http://playgroundgem.org/',
#   'city': 'Ft. Walton Beach'},
#  {'title': 'Southwest Florida Fossil Society',
#   'state': 'Florida',
#   'link': 'http://www.southwestfloridafossilsociety.org/',
#   'city': 'Punta Gorda'},
#  {'title': 'St Lucie County Rock and Gem Club',
#   'state': 'Florida',
#   'link': 'http://www.slcrockandgem.org/',
#   'city': 'Port St Lucie'},
#  {'title': 'Suncoast Gem and Mineral Society',
#   'state': 'Florida',
#   'link': 'http://sgams.com/',
#   'city': 'St Petersburg'},
#  {'title': 'Tampa Bay Fossil Club',
#   'state': 'Florida',
#   'link': 'http://www.tampabayfossilclub.com/',
#   'city': 'Palm Harbor'},
#  {'title': 'Tampa Bay Mineral & Science Club, Inc.',
#   'state': 'Florida',
#   'link': 'http://www.tampabayrockclub.com/',
#   'city': 'Tampa'},
#  {'title': 'The Villages Gem and Mineral Society',
#   'state': 'Florida',
#   'link': 'http://www.thevillagesgemandmineralsociety.com/',
#   'city': 'The Villages'},
#  {'title': 'Tomoka Faceters Guild',
#   'state': 'Florida',
#   'link': 'http://www.tomokafacetersguild.org/index.html',
#   'city': 'Palm Coast'},
#  {'title': 'Withlacoochee Rockhounds',
#   'state': 'Florida',
#   'link': 'http://www.withlacoocheerockhounds.com/',
#   'city': 'Spring Hill'},
#  {'title': 'Athens Rock and Gem Club',
#   'state': 'Georgia',
#   'link': 'http://www.athensrockandgemclub.org/',
#   'city': 'Athens'},
#  {'title': 'Augusta Gem & Mineral Society',
#   'state': 'Georgia',
#   'link': 'http://agams.club/',
#   'city': 'Augusta'},
#  {'title': 'Cobb County Gem and Mineral Society',
#   'state': 'Georgia',
#   'link': 'https://www.ccgms.org/',
#   'city': 'Marietta'},
#  {'title': 'Georgia Mineral Society, Inc.',
#   'state': 'Georgia',
#   'link': 'http://www.gamineral.org/',
#   'city': 'Norcross'},
#  {'title': 'Mid-Georgia Gem and Mineral Society',
#   'state': 'Georgia',
#   'link': 'http://midgagmsorg.ipage.com/',
#   'city': 'Macon'},
#  {'title': 'Rome Georgia Mineral Society Inc.',
#   'state': 'Georgia',
#   'link': 'https://rogams.wordpress.com/',
#   'city': 'Rome'},
#  {'title': "Hui Pohaku 'O Hawai'i Rock & Mineral Society of Hawai'i, Inc.",
#   'state': 'Hawaii',
#   'link': 'http://pohakugalore.net/Hui_pohaku/Hiu_pohaku_1.html',
#   'city': 'Honolulu'},
#  {'title': 'Hells Canyon Gem Club, Inc.',
#   'state': 'Idaho',
#   'link': 'http://www.hellscanyongemclub.com/',
#   'city': 'Lewiston'},
#  {'title': 'Idaho Falls Gem & Mineral Society',
#   'state': 'Idaho',
#   'link': 'http://ifgemmineral.weebly.com/',
#   'city': 'Idaho Falls'},
#  {'title': 'Idaho Gem Club, Inc.',
#   'state': 'Idaho',
#   'link': 'http://www.idahogemclub.com/',
#   'city': 'Boise'},
#  {'title': 'Magic Valley Gem Club',
#   'state': 'Idaho',
#   'link': 'http://magicvalleygemclub.org/',
#   'city': 'Twin Falls'},
#  {'title': 'North Idaho Mineral Club',
#   'state': 'Idaho',
#   'link': 'http://www.northidahomineralclub.com/',
#   'city': "Coeur d'Alene"},
#  {'title': 'Owyhee Gem & Mineral Society',
#   'state': 'Idaho',
#   'link': 'http://www.owyheerocks.com/',
#   'city': 'Caldwell'},
#  {'title': 'Pend Oreille Rock and Gem Club',
#   'state': 'Idaho',
#   'link': 'https://pendoreillerockandgemclub.wordpress.com/',
#   'city': 'Oldtown'},
#  {'title': 'Southeast Idaho Gem and Mineral Society',
#   'state': 'Idaho',
#   'link': 'https://www.facebook.com/SEIGMS',
#   'city': 'Boise'},
#  {'title': 'Black Hawk Gem & Mineral Club',
#   'state': 'Illinois',
#   'link': 'http://www.blackhawkgemandmineralclub.com/',
#   'city': 'Rock Island'},
#  {'title': 'Central Illinois Gem & Mineral Club',
#   'state': 'Illinois',
#   'link': 'http://rmkapta.wixsite.com/cigmc',
#   'city': 'Decatur'},
#  {'title': 'Chicago Rocks & Minerals Society',
#   'state': 'Illinois',
#   'link': 'http://www.chicagorocks.org/',
#   'city': 'Skokie'},
#  {'title': 'Elgin Rock Club',
#   'state': 'Illinois',
#   'link': 'http://elginrockclub.org/',
#   'city': 'Elgin'},
#  {'title': 'Geodeland Earth Science Clubs, Inc.',
#   'state': 'Illinois',
#   'link': 'http://www.geodeland.com/',
#   'city': 'Macomb'},
#  {'title': 'Lincoln Orbit Earth Science Society',
#   'state': 'Illinois',
#   'link': 'http://www.loess.org/',
#   'city': 'Springfield'},
#  {'title': 'Midwest Historical Research Society',
#   'state': 'Illinois',
#   'link': 'http://www.mhrsusa.com/',
#   'city': 'Chicago'},
#  {'title': 'Northwest Illinois Rock Club',
#   'state': 'Illinois',
#   'link': 'http://nwilrockclubfrpt.blogspot.com/',
#   'city': 'Freeport'},
#  {'title': 'Peoria Academy of Science Geology Section',
#   'state': 'Illinois',
#   'link': 'http://www.pasgeology.com/',
#   'city': 'Peoria'},
#  {'title': 'Southern Illinois Earth Science Club',
#   'state': 'Illinois',
#   'link': 'http://www.siesclub.org/',
#   'city': 'Benton'},
#  {'title': 'West Central Illinois Rock & Mineral Club',
#   'state': 'Illinois',
#   'link': 'http://www.rockchatter.com/',
#   'city': 'Macomb'},
#  {'title': 'West Suburban Lapidary Club',
#   'state': 'Illinois',
#   'link': 'http://www.westsuburbanlapidaryclub.com/',
#   'city': 'Elmhurst'},
#  {'title': '500 Earth Sciences Club',
#   'state': 'Indiana',
#   'link': 'http://www.500earthsciencesclub.org/',
#   'city': 'Indianapolis'},
#  {'title': 'Brown County Rock and Mineral Club',
#   'state': 'Indiana',
#   'link': 'http://browncountyrock.webs.com/',
#   'city': 'Nashville'},
#  {'title': 'Calumet Gem & Mineral Society',
#   'state': 'Indiana',
#   'link': 'https://www.facebook.com/calumetrockclub',
#   'city': 'Crown Point'},
#  {'title': 'Evansville Lapidary Society',
#   'state': 'Indiana',
#   'link': 'http://evansvillelapidarysociety.tumblr.com/',
#   'city': 'Evansville'},
#  {'title': 'Eastern Indiana Gem & Geological Society, Inc.',
#   'state': 'Indiana',
#   'link': 'http://eiggs.weebly.com/',
#   'city': 'Richmond'},
#  {'title': 'Lawrence County Rock Club, Inc',
#   'state': 'Indiana',
#   'link': 'http://www.lawrencecountyrockclub.org/',
#   'city': 'Bedford'},
#  {'title': 'Michiana Gem & Mineral Society, Inc.',
#   'state': 'Indiana',
#   'link': 'http://www.michianagms.org/',
#   'city': 'South Bend'},
#  {'title': 'Three Rivers Gem & Mineral Society',
#   'state': 'Indiana',
#   'link': 'http://3riversgem_mineral.tripod.com/',
#   'city': 'Fort Wayne'},
#  {'title': 'Cedar Valley Rocks and Minerals Society',
#   'state': 'Iowa',
#   'link': 'http://www.cedarvalleyrockclub.org/',
#   'city': 'Cedar Rapids'},
#  {'title': 'Des Moines Lapidary Society',
#   'state': 'Iowa',
#   'link': 'http://dmlapidary.org/',
#   'city': 'Des Moines'},
#  {'title': 'Geology Club @ Cornell College',
#   'state': 'Iowa',
#   'link': 'http://orgs.cornellcollege.edu/geo_club/',
#   'city': 'Mount Vernon'},
#  {'title': 'Iowa State University Geology Club',
#   'state': 'Iowa',
#   'link': 'https://www.facebook.com/ISUGEOCLUB/',
#   'city': 'Ames'},
#  {'title': 'River Valley Rockhounds',
#   'state': 'Iowa',
#   'link': 'http://amfed.org/mwf/states/Iowa/RiverValley.html',
#   'city': 'Fort Dodge'},
#  {'title': 'The Sac & Fox Lapidary Club',
#   'state': 'Iowa',
#   'link': 'http://members.iowatelecom.net/billrath/rock_club.html',
#   'city': 'Fairfield'},
#  {'title': 'McPherson Gem and Mineral Club',
#   'state': 'Kansas',
#   'link': 'https://mcphersongemandmineralclub.org/',
#   'city': 'McPherson'},
#  {'title': 'Olathe Gem and Mineral Society',
#   'state': 'Kansas',
#   'link': 'http://olathegemclub.com/',
#   'city': 'Kansas City'},
#  {'title': 'Topeka Gem & Mineral Society',
#   'state': 'Kansas',
#   'link': 'http://www.topekagms.org/',
#   'city': 'Topeka'},
#  {'title': 'Wichita Gem and Mineral Society',
#   'state': 'Kansas',
#   'link': 'http://www.wgmsks.org/',
#   'city': 'Wichita'},
#  {'title': 'Wichita Paleontological Society',
#   'state': 'Kansas',
#   'link': 'http://www.reocities.com/CapeCanaveral/Hangar/4265/home.html',
#   'city': 'Wichita'},
#  {'title': 'Blue Grass Gem & Mineral Club of Central Kentucky',
#   'state': 'Kentucky',
#   'link': 'http://bggamc.homestead.com/',
#   'city': 'Lexington'},
#  {'title': 'KYANA Geological Society',
#   'state': 'Kentucky',
#   'link': 'http://www.kyanageo.org/',
#   'city': 'Louisville'},
#  {'title': 'Kentucky Paleontological Society',
#   'state': 'Kentucky',
#   'link': 'http://www.uky.edu/OtherOrgs/KPS/',
#   'city': 'Lexington'},
#  {'title': 'Ark-La-Tex Gem & Mineral Society',
#   'state': 'Louisiana',
#   'link': 'http://larockclub.com/',
#   'city': 'Shreveport'},
#  {'title': 'Baton Rouge Gem & Mineral Society',
#   'state': 'Louisiana',
#   'link': 'http://www.brgemandmineral.org/',
#   'city': 'Baton Rouge'},
#  {'title': 'DeRidder Gem & Mineral Society',
#   'state': 'Louisiana',
#   'link': 'https://www.facebook.com/DeRidder-Gem-Mineral-Society-1123146734440993/',
#   'city': 'Leesville'},
#  {'title': 'Kennebec Rocks and Minerals Club',
#   'state': 'Maine',
#   'link': 'http://kennebec-rocksandminerals.com/',
#   'city': 'Winthrop'},
#  {'title': 'Maine Mineralogical & Geological Society',
#   'state': 'Maine',
#   'link': 'http://mainemineralclub.org/',
#   'city': 'Portland'},
#  {'title': 'Oxford County Mineral and Gem Association',
#   'state': 'Maine',
#   'link': 'http://ocmgassoc.blogspot.com/',
#   'city': 'South Paris'},
#  {'title': 'Penobscot Mineral and Lapidary Club',
#   'state': 'Maine',
#   'link': 'http://penobscotminerallapidaryclub.com/index.html',
#   'city': 'Milford'},
#  {'title': 'American Fossil Federation',
#   'state': 'Maryland',
#   'link': 'http://americanfossilfederation.org/Home.html',
#   'city': 'Bowie'},
#  {'title': 'Baltimore Mineral Society',
#   'state': 'Maryland',
#   'link': 'http://www.baltimoremineralsociety.org/',
#   'city': 'Baltimore'},
#  {'title': 'Calvert Marine Museum Fossil Club',
#   'state': 'Maryland',
#   'link': 'http://www.calvertmarinemuseum.com/209/Fossil-Club',
#   'city': 'Solomons'},
#  {'title': 'Central Maryland Rock and Mineral Collectors Exchange',
#   'state': 'Maryland',
#   'link': 'https://www.meetup.com/rockhounds/',
#   'city': 'Elkridge'},
#  {'title': 'Chesapeake Gem & Mineral Society',
#   'state': 'Maryland',
#   'link': 'http://www.chesapeakegemandmineral.org/',
#   'city': 'Baltimore'},
#  {'title': 'Gem Cutters Guild of Baltimore, Inc.',
#   'state': 'Maryland',
#   'link': 'http://www.gemcuttersguild.com/',
#   'city': 'Baltimore'},
#  {'title': 'Gem, Lapidary, and Mineral Society of Montgomery County, MD., Inc.',
#   'state': 'Maryland',
#   'link': 'http://www.glmsmc.com/',
#   'city': 'Rockville'},
#  {'title': 'Maryland Geological Society',
#   'state': 'Maryland',
#   'link': 'http://www.ecphora.net/mgs/',
#   'city': 'Bowie'},
#  {'title': 'Micromineralogists of the National Capital Area',
#   'state': 'Maryland',
#   'link': 'http://dcmicrominerals.org/',
#   'city': 'Washington, DC'},
#  {'title': 'Patuxent Lapidary Guild',
#   'state': 'Maryland',
#   'link': 'http://www.patuxentlapidary.org/',
#   'city': 'Annapolis'},
#  {'title': 'Southern Maryland Rock and Mineral Club',
#   'state': 'Maryland',
#   'link': 'http://www.smrmc.org/',
#   'city': 'Clinton'},
#  {'title': 'The Mineralogical Society of the District of Columbia',
#   'state': 'Maryland',
#   'link': 'http://www.mineralogicalsocietyofdc.org/',
#   'city': 'Washington, DC'},
#  {'title': 'Boston Mineral Club, Inc.',
#   'state': 'Massachusetts',
#   'link': 'http://www.bostonmineralclub.org/',
#   'city': 'Boston'},
#  {'title': 'Connecticut Valley Mineral Club',
#   'state': 'Massachusetts',
#   'link': 'http://www.cvmineralclub.org/',
#   'city': 'Springfield'},
#  {'title': 'Micromounters of New England',
#   'state': 'Massachusetts',
#   'link': 'http://micromountersofnewengland.org/',
#   'city': 'Chemlsford'},
#  {'title': 'Nashoba Valley Mineralogical Society',
#   'state': 'Massachusetts',
#   'link': 'http://www.americantowns.com/ma/westford/organization/nashoba_valley_mineralogical_society',
#   'city': 'Westford'},
#  {'title': 'North Shore Rock & Mineral Club of Massachusetts',
#   'state': 'Massachusetts',
#   'link': 'http://www.northshorerock.org/',
#   'city': 'South Hamilton'},
#  {'title': 'Northern Berkshire Mineral Club',
#   'state': 'Massachusetts',
#   'link': 'http://nbmclub.webs.com/',
#   'city': 'North Adams'},
#  {'title': 'Southeastern Massachusetts Mineral Club',
#   'state': 'Massachusetts',
#   'link': 'http://semmc.com/',
#   'city': 'Bridgewater'},
#  {'title': 'Worcester Mineral Club',
#   'state': 'Massachusetts',
#   'link': 'http://worcestermineralclub.org/',
#   'city': 'Worcester'},
#  {'title': 'Big Rapids Rock, Gem & Mineral Club',
#   'state': 'Michigan',
#   'link': 'https://sites.google.com/site/bigrapidsrockgemmineralclub/',
#   'city': 'Big Rapids'},
#  {'title': 'Central Michigan Lapidary and Mineral Society',
#   'state': 'Michigan',
#   'link': 'http://michrocks.org/',
#   'city': 'Lansing'},
#  {'title': 'Copper Country Rock and Mineral Club',
#   'state': 'Michigan',
#   'link': 'http://www.ccrmc.info/',
#   'city': 'Dollar Bay'},
#  {'title': 'Flint Rock and Gem Club',
#   'state': 'Michigan',
#   'link': 'http://www.flintrockandgem.org/',
#   'city': 'Flint'},
#  {'title': 'Grand Traverse Area Rock and Mineral Club',
#   'state': 'Michigan',
#   'link': 'http://tcrockhounds.com/',
#   'city': 'Traverse City'},
#  {'title': 'Indian Mounds Rock & Mineral Club',
#   'state': 'Michigan',
#   'link': 'http://www.indianmoundsrockclub.com/',
#   'city': 'Wyoming'},
#  {'title': 'Ishpeming Rock and Mineral Club',
#   'state': 'Michigan',
#   'link': 'http://www.ishpemingrocks.org/',
#   'city': 'Ishpeming'},
#  {'title': 'Kalamazoo Geological & Mineral Society',
#   'state': 'Michigan',
#   'link': 'http://kalamazoorockclub.org/',
#   'city': 'Kalamazoo'},
#  {'title': 'Livingston Gem & Mineral Society',
#   'state': 'Michigan',
#   'link': 'http://www.livingstongemandmineralsociety.com/',
#   'city': 'Howell'},
#  {'title': 'Michigan Gem & Mineral Society',
#   'state': 'Michigan',
#   'link': 'http://mgmsrockclub.com/',
#   'city': 'Michigan Center'},
#  {'title': 'Michigan Mineralogical Society',
#   'state': 'Michigan',
#   'link': 'https://www.michmin.org/',
#   'city': 'Bloomfield Hills'},
#  {'title': 'Mid-Michigan Rock Club',
#   'state': 'Michigan',
#   'link': 'http://www.midmichrockclub.com/?Page=1',
#   'city': 'Midland'},
#  {'title': "Midwest Faceters' Guild",
#   'state': 'Michigan',
#   'link': 'http://www.midwestfaceters.org/',
#   'city': 'Grand Rapids'},
#  {'title': 'Midwest Mineralological & Lapidary Society',
#   'state': 'Michigan',
#   'link': 'http://www.mmls.us/',
#   'city': 'Taylor'},
#  {'title': 'Mikenauk Rock and Gem Club',
#   'state': 'Michigan',
#   'link': 'http://mikenaukclub.weebly.com/',
#   'city': 'Roscommon'},
#  {'title': 'Mount Clemens Gem & Lapidary Society',
#   'state': 'Michigan',
#   'link': 'http://mcgls.org/',
#   'city': 'Mt. Clemens'},
#  {'title': 'Oakland County Earth Science Club',
#   'state': 'Michigan',
#   'link': 'http://www.ocesc.com/',
#   'city': 'Waterford'},
#  {'title': 'Roamin Club',
#   'state': 'Michigan',
#   'link': 'https://roaminrockclub.weebly.com/',
#   'city': 'Livonia'},
#  {'title': 'StateLine Gem & Mineral Society',
#   'state': 'Michigan',
#   'link': 'http://statelinegms.com/',
#   'city': 'Morenci'},
#  {'title': 'Tulip City Gem & Mineral Club, Inc.',
#   'state': 'Michigan',
#   'link': 'http://www.tulipcity.org/',
#   'city': 'Holland'},
#  {'title': 'Anoka County Gem & Mineral Club',
#   'state': 'Minnesota',
#   'link': 'http://www.amfed.org/mwf/states/Minnesota/AnokaGem.html',
#   'city': 'Minneapolis'},
#  {'title': 'Cuyuna Rock, Gem and Mineral Society',
#   'state': 'Minnesota',
#   'link': 'http://cuyunarockclub.org/wp/',
#   'city': 'Brainerd'},
#  {'title': 'Minnesota Mineral Club',
#   'state': 'Minnesota',
#   'link': 'http://minnesotamineralclub.org/',
#   'city': 'Falcon Heights'},
#  {'title': 'Minnesota Valley Gem & Mineral Club',
#   'state': 'Minnesota',
#   'link': 'http://www.mnvalleygemandmineralclub.com/',
#   'city': 'Mankato'},
#  {'title': 'St Croix Rockhounds',
#   'state': 'Minnesota',
#   'link': 'http://stcroixrockhounds.org/',
#   'city': 'Stillwater'},
#  {'title': 'Harrison County Gem & Mineral Society, Inc.',
#   'state': 'Mississippi',
#   'link': 'http://www.gulfportgems.org/',
#   'city': 'Gulfport'},
#  {'title': 'Mississippi Gem & Mineral Society',
#   'state': 'Mississippi',
#   'link': 'http://missgems.org/',
#   'city': 'Jackson'},
#  {'title': 'Mississippi Geological Society',
#   'state': 'Mississippi',
#   'link': 'http://www.missgeo.com/',
#   'city': 'Jackson'},
#  {'title': 'Mississippi Gulf Coast Gem and Mineral Society',
#   'state': 'Mississippi',
#   'link': 'http://www.mgcgms.org/',
#   'city': 'Ocean Springs'},
#  {'title': 'North Mississippi Gem and Mineral Society',
#   'state': 'Mississippi',
#   'link': 'http://www.nmgms.org/',
#   'city': 'Tupelo'},
#  {'title': 'Central Missouri Rock and Lapidary Club',
#   'state': 'Missouri',
#   'link': 'http://www.cmrlc.org/',
#   'city': 'Columbia'},
#  {'title': 'Independence Gem & Mineral Society',
#   'state': 'Missouri',
#   'link': 'http://www.igams.co/',
#   'city': 'Independence'},
#  {'title': 'Missouri Valley Gem & Mineral Society',
#   'state': 'Missouri',
#   'link': 'http://www.movalleyrockclub.com/',
#   'city': 'St. Joseph'},
#  {'title': 'Mozarkite Society of Lincoln, Inc.',
#   'state': 'Missouri',
#   'link': 'http://www.mozarkite.com/',
#   'city': 'Lincoln'},
#  {'title': 'Ozark Mountain Gem & Mineral Society',
#   'state': 'Missouri',
#   'link': 'https://www.facebook.com/omgms.57',
#   'city': 'Springfield'},
#  {'title': 'Rock Hobby Club of Greater Saint Louis',
#   'state': 'Missouri',
#   'link': 'xxxxxhttp://rockhobby.stlearthsci.org/Home.aspxxxxxx',
#   'city': 'St. Louis'},
#  {'title': 'Rockwood Gem & Mineral Society',
#   'state': 'Missouri',
#   'link': 'http://rockwood.stlearthsci.org/',
#   'city': 'St. Louis'},
#  {'title': 'St. Louis Mineral & Gem Society',
#   'state': 'Missouri',
#   'link': 'http://www.stlrockclub.com/',
#   'city': 'St. Louis'},
#  {'title': 'Show Me Gems & Minerals Club, Inc.',
#   'state': 'Missouri',
#   'link': 'http://showme.stlearthsci.org/',
#   'city': 'St. Peters'},
#  {'title': 'Show-Me Rockhounds Kansas City',
#   'state': 'Missouri',
#   'link': 'https://showmerockhounds.com/',
#   'city': 'Kansas City'},
#  {'title': 'Billings Gem & Mineral Club, Inc.',
#   'state': 'Montana',
#   'link': 'http://www.billingsgemclub.com/',
#   'city': 'Billings'},
#  {'title': 'Bitterroot Gem & Mineral Society',
#   'state': 'Montana',
#   'link': 'http://www.ravalligemandmineralclub.org/',
#   'city': 'Corvallis'},
#  {'title': 'Bozeman Gem and Mineral Club',
#   'state': 'Montana',
#   'link': 'http://bozemangemandmineralclub.com/',
#   'city': 'Bozeman'},
#  {'title': 'Hellgate Mineral Society',
#   'state': 'Montana',
#   'link': 'https://www.facebook.com/HellgateMineralSociety/',
#   'city': 'Missoula'},
#  {'title': 'Kalispell Rockhound Club',
#   'state': 'Montana',
#   'link': 'http://www.kalispellrockhounds.org/',
#   'city': 'Kalispell'},
#  {'title': 'Lincoln Gem & Mineral Club, Inc.',
#   'state': 'Nebraska',
#   'link': 'https://www.lincolngemmineralclub.org/',
#   'city': 'Lincoln'},
#  {'title': 'Comstock Gold Prospectors',
#   'state': 'Nevada',
#   'link': 'http://cgpgold.org/',
#   'city': 'Reno'},
#  {'title': 'Great Basin Gem & Mineral Club',
#   'state': 'Nevada',
#   'link': 'http://greatbasingemandmineralclub.rocks/',
#   'city': 'Carson City'},
#  {'title': 'High Desert Rockers',
#   'state': 'Nevada',
#   'link': 'https://highdesertrockers.wordpress.com/',
#   'city': 'Carson City'},
#  {'title': 'Nye Gold Seekers',
#   'state': 'Nevada',
#   'link': 'http://nyegoldseekers.webs.com/',
#   'city': 'Pahrump'},
#  {'title': 'Reno Gem and Mineral Society',
#   'state': 'Nevada',
#   'link': 'http://www.renorockhounds.com/',
#   'city': 'Reno'},
#  {'title': 'Southern Nevada Gem and Mineral Society',
#   'state': 'Nevada',
#   'link': 'http://www.snvgms.org/',
#   'city': 'Las Vegas'},
#  {'title': 'Capital Mineral Club',
#   'state': 'New Hampshire',
#   'link': 'http://www.capitalmineralclub.org/',
#   'city': 'Concord'},
#  {'title': 'Keene Mineral Club',
#   'state': 'New Hampshire',
#   'link': 'https://sites.google.com/site/keenemineralclub/home',
#   'city': 'Keene'},
#  {'title': 'Saco Valley Gem and Mineral Club',
#   'state': 'New Hampshire',
#   'link': 'http://www.sacovalleygemandmineralclub.org/',
#   'city': 'Conway'},
#  {'title': 'Southeastern New Hampshire Mineral Club',
#   'state': 'New Hampshire',
#   'link': 'https://www.senhmc.org/',
#   'city': 'Dover'},
#  {'title': 'Cape Atlantic Rockhounds Inc.',
#   'state': 'New Jersey',
#   'link': 'http://www.capeatlanticrockhounds.com/',
#   'city': 'Cologne'},
#  {'title': 'Delaware Valley Earth Science Society',
#   'state': 'New Jersey',
#   'link': 'http://www.dvess.org/',
#   'city': 'Woodbury'},
#  {'title': 'Friends of Mineralogy - New Jersey Chapter',
#   'state': 'New Jersey',
#   'link': 'https://fomnj.wordpress.com/',
#   'city': 'Marlboro Township'},
#  {'title': 'Morris Museum Mineralogical Society',
#   'state': 'New Jersey',
#   'link': 'http://morrismuseum.org/mineral-society/',
#   'city': 'Morristown'},
#  {'title': 'New Jersey Mineralogical Society, Inc',
#   'state': 'New Jersey',
#   'link': 'http://www.njmin.org/',
#   'city': 'Mountainside'},
#  {'title': 'North Jersey Mineralogical Society, Inc.',
#   'state': 'New Jersey',
#   'link': 'http://www.nojms.webs.com/',
#   'city': 'Paterson'},
#  {'title': 'Albuquerque Gem & Mineral Club',
#   'state': 'New Mexico',
#   'link': 'http://www.agmc.info/',
#   'city': 'Albuquerque'},
#  {'title': 'Carlsbad Gem and Mineral Society',
#   'state': 'New Mexico',
#   'link': 'http://www.carlsbadgms.org/',
#   'city': 'Carlsbad'},
#  {'title': 'Deming Gem & Mineral Society',
#   'state': 'New Mexico',
#   'link': 'http://www.thedgms.com/',
#   'city': 'Deming'},
#  {'title': 'Grant County Rolling Stones Gem & Mineral Society, Inc.',
#   'state': 'New Mexico',
#   'link': 'http://rollingstonesgms.blogspot.com/',
#   'city': 'Silver City'},
#  {'title': 'Los Alamos Geological Society',
#   'state': 'New Mexico',
#   'link': 'http://pweb.netcom.com/~hoffmans/LAGS.html',
#   'city': 'Los Alamos'},
#  {'title': 'Buffalo Geological Society, Inc.',
#   'state': 'New York',
#   'link': 'http://www.bgsny.org/',
#   'city': 'Buffalo'},
#  {'title': 'Capital District Mineral Club',
#   'state': 'New York',
#   'link': 'http://capitaldistrictmineralclub.com/',
#   'city': 'Albany'},
#  {'title': 'Gem and Mineral Society of Syracuse, Inc.',
#   'state': 'New York',
#   'link': 'http://www.gmss.us/',
#   'city': 'Syracuse'},
#  {'title': 'Island Rockhounds Inc.',
#   'state': 'New York',
#   'link': 'http://www.islandrockhounds.org/',
#   'city': 'Bellmore'},
#  {'title': 'Long Island Mineral & Geology Society',
#   'state': 'New York',
#   'link': 'http://www.limineralandgeology.com/LiMags/Home.html',
#   'city': 'Jamesport'},
#  {'title': 'Mid-Hudson Valley Gem and Mineral Society Inc.',
#   'state': 'New York',
#   'link': 'http://mhvgms.org/index.html',
#   'city': 'Poughkeepsie'},
#  {'title': 'Nassau Mineral Club',
#   'state': 'New York',
#   'link': 'http://nassaumineralclub.org/',
#   'city': 'Glen Cove'},
#  {'title': 'New York Mineralogical Club',
#   'state': 'New York',
#   'link': 'http://www.newyorkmineralogicalclub.org/',
#   'city': 'NYC'},
#  {'title': 'New York Paleontological Society',
#   'state': 'New York',
#   'link': 'http://www.nyps.org/index.htm',
#   'city': 'NYC'},
#  {'title': 'Orange County Mineral Society',
#   'state': 'New York',
#   'link': 'http://www.orangecountymineralsocietynewyork.com/',
#   'city': 'Middletown'},
#  {'title': 'Rochester Academy of Science',
#   'state': 'New York',
#   'link': 'http://www.rasny.org/',
#   'city': 'Rochester'},
#  {'title': 'Rochester Lapiday Society',
#   'state': 'New York',
#   'link': 'http://www.rochesterlapidary.org/',
#   'city': 'Rochester'},
#  {'title': 'St. Lawrence County Rock & Mineral Club',
#   'state': 'New York',
#   'link': 'http://stlawrencecountymineralclub.org/',
#   'city': 'Canton'},
#  {'title': 'Suffolk Gem & Mineral Club',
#   'state': 'New York',
#   'link': 'http://www.suffolkgem.com/',
#   'city': 'Bay Shore'},
#  {'title': 'Wayne County Gem and Mineral Club',
#   'state': 'New York',
#   'link': 'http://www.wcgmc.org/',
#   'city': 'Newark'},
#  {'title': 'Cape Fear Mineral & Gem Society',
#   'state': 'North Carolina',
#   'link': 'http://www.mercergarden.com/GemClub.html',
#   'city': 'Fayetteville'},
#  {'title': 'Catawba Valley Gem & Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.cvgmc.com/',
#   'city': 'Hickory'},
#  {'title': 'Central North Carolina Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.centralncmineralclub.org/',
#   'city': 'Chapel Hill'},
#  {'title': 'Charlotte Gem & Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.charlottegem.com/',
#   'city': 'Charlotte'},
#  {'title': 'Forsyth Gem and Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.forsythgemclub.com/fgmcmain.html',
#   'city': 'Winston-Salem'},
#  {'title': 'Gaston Gem, Mineral and Faceters Club',
#   'state': 'North Carolina',
#   'link': 'http://gastongemclub.weebly.com/',
#   'city': 'Gastonia'},
#  {'title': 'Gem & Mineral Society of Franklin',
#   'state': 'North Carolina',
#   'link': 'http://www.fgmm.org/',
#   'city': 'Franklin'},
#  {'title': 'Greensboro Gem & Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.ggmc-rockhounds.com/',
#   'city': 'Greensboro'},
#  {'title': 'Henderson County Gem and Mineral Society',
#   'state': 'North Carolina',
#   'link': 'http://hcgms.com/index.html',
#   'city': 'Hendersonville'},
#  {'title': 'Mountain Area Gem and Mineral Association (MAGMA)',
#   'state': 'North Carolina',
#   'link': 'http://www.wncrocks.com/magma/magma.html',
#   'city': 'Asheville'},
#  {'title': 'North Carolina Fossil Club',
#   'state': 'North Carolina',
#   'link': 'http://www.ncfossilclub.org/',
#   'city': 'Raleigh'},
#  {'title': 'Southern Appalachian Mineral Society',
#   'state': 'North Carolina',
#   'link': 'http://www.main.nc.us/sams/',
#   'city': 'Asheville'},
#  {'title': 'Tar Heel Gem & Mineral Club',
#   'state': 'North Carolina',
#   'link': 'http://www.tarheelclub.org/',
#   'city': 'Raleigh'},
#  {'title': 'Central Dakota Gem & Mineral Society',
#   'state': 'North Dakota',
#   'link': 'https://ndrockclub.org/',
#   'city': 'Bismarck'},
#  {'title': 'Brukner Gem and Mineral Club',
#   'state': 'Ohio',
#   'link': 'http://www.bruknergemandmineralclub.com/',
#   'city': 'Troy'},
#  {'title': 'Cincinnati Mineral Society',
#   'state': 'Ohio',
#   'link': 'http://mineralsociety.org/',
#   'city': 'Cincinnati'},
#  {'title': 'Columbus Rock and Mineral Society',
#   'state': 'Ohio',
#   'link': 'http://www.columbusrockandmineralsociety.org/',
#   'city': 'Columbus'},
#  {'title': 'Dayton Gem & Mineral Society',
#   'state': 'Ohio',
#   'link': 'https://www.facebook.com/The-Dayton-Gem-Mineral-Society-140478502678195/',
#   'city': 'Kettering'},
#  {'title': 'Dry Dredgers',
#   'state': 'Ohio',
#   'link': 'http://drydredgers.org/',
#   'city': 'Cincinnati'},
#  {'title': 'Greater Cincinati Lapidary and Faceting Society',
#   'state': 'Ohio',
#   'link': 'http://cincinnatilapidary.weebly.com/',
#   'city': 'Loveland'},
#  {'title': 'North Coast Fossil Club',
#   'state': 'Ohio',
#   'link': 'http://ncfclub.org/',
#   'city': 'Cleveland'},
# ...
#   'state': 'Pennsylvania',
#   'link': 'http://leidymicroscopical.com/',
#   'city': 'Fairless Hills'},
#  {'title': 'Mason-Dixon Rock, Mineral, Gemological, & Lapidary Club',
#   'state': 'Pennsylvania',
#   'link': 'http://topgemz.com/',
#   'city': 'Hanover'},
#  {'title': 'Mineralogical Society of Northeastern Pennsylvania',
#   'state': 'Pennsylvania',
#   'link': 'http://msnepa.org/',
#   'city': 'Moosic'},
#  {'title': 'Monongahela Rockhounds',
#   'state': 'Pennsylvania',
#   'link': 'http://www.monongahelarockhounds.org/',
#   'city': 'Pittsburgh'},
#  {'title': 'Monroe County Earth Science Association',
#   'state': 'Pennsylvania',
#   'link': 'http://www.mdsysconsulting.com/MCESA/',
#   'city': 'Stroudsburg'},
#  {'title': 'Moraine Rockbusters',
#   'state': 'Pennsylvania',
#   'link': 'http://www.morainerockbusters.org/',
#   'city': 'Mars'},
#  {'title': 'Nittany Mineralogical Society',
#   'state': 'Pennsylvania',
#   'link': 'http://www.nittanymineral.org/',
#   'city': 'State College'},
#  {'title': 'Pennsylvania Earth Sciences Association',
#   'state': 'Pennsylvania',
#   'link': 'http://www.mineralfest.com/',
#   'city': 'Whitehall'},
#  {'title': 'Philadelphia Mineralogical Society',
#   'state': 'Pennsylvania',
#   'link': 'http://www.phillyrocks.org/',
#   'city': 'Philadelphia'},
#  {'title': 'Pittsburgh Geological Society',
#   'state': 'Pennsylvania',
#   'link': 'http://www.pittsburghgeologicalsociety.org/index.html',
#   'city': 'Pittsburgh'},
#  {'title': 'Tuscarora Lapidary Society',
#   'state': 'Pennsylvania',
#   'link': 'http://www.lapidary.org/',
#   'city': 'Brookhaven'},
#  {'title': 'Rhode Island Mineral Hunters, Inc.',
#   'state': 'Rhode Island',
#   'link': 'http://rimh.us/',
#   'city': 'Warwick'},
#  {'title': 'Aiken Gem and Mineral Society',
#   'state': 'South Carolina',
#   'link': 'http://www.aikengmfs.org/',
#   'city': 'Aiken'},
#  {'title': 'Columbia Gem & Mineral Society',
#   'state': 'South Carolina',
#   'link': 'http://www.cgams.org/',
#   'city': 'Columbia'},
#  {'title': 'Lowcountry Gem and Mineral Society',
#   'state': 'South Carolina',
#   'link': 'http://lowcountrygemandmineralsociety.org/',
#   'city': 'North Charleston'},
#  {'title': 'Pendleton District Gem and Mineral Society',
#   'state': 'South Carolina',
#   'link': 'http://www.woodsmere.com/pdgms/',
#   'city': 'Central'},
#  {'title': 'Western South Carolina Gem and Mineral Society',
#   'state': 'South Carolina',
#   'link': 'http://www.wescagem.org/',
#   'city': 'Greenville'},
#  {'title': 'Sioux Empire Gem and Mineral Society',
#   'state': 'South Dakota',
#   'link': 'http://www.segams.org/',
#   'city': 'Sioux Falls'},
#  {'title': 'Western Dakota Gem & Mineral Society',
#   'state': 'South Dakota',
#   'link': 'http://www.wdgms.org/',
#   'city': 'Rapid City'},
#  {'title': 'Knoxville Gem & Mineral Society',
#   'state': 'Tennessee',
#   'link': 'http://www.knoxrocks.org/',
#   'city': 'Knoxville'},
#  {'title': 'Memphis Archaeological & Geological Society',
#   'state': 'Tennessee',
#   'link': 'http://www.memphisgeology.org/',
#   'city': 'Memphis'},
#  {'title': 'Middle Tennessee Rockhounds',
#   'state': 'Tennessee',
#   'link': 'http://www.rockhound.org/',
#   'city': 'Nashville'},
#  {'title': 'Mid-Tennessee Gem and Mineral Society',
#   'state': 'Tennessee',
#   'link': 'http://www.mtgms.org/',
#   'city': 'Murfreesboro, Donelson, Tullahoma'},
#  {'title': 'Arlington Gem and Mineral Club',
#   'state': 'Texas',
#   'link': 'http://www.agemclub.org/',
#   'city': 'Arlington'},
#  {'title': 'Austin Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.austingemandmineral.org/index.html',
#   'city': 'Austin'},
#  {'title': 'Central Texas Gem & Mineral Society',
#   'state': 'Texas',
#   'link': 'http://rockclub.txol.net/',
#   'city': 'Abilene'},
#  {'title': 'Chihuahuan Desert Gem and Mineral Club',
#   'state': 'Texas',
#   'link': 'http://www.cdgmc.org/',
#   'city': 'Alpine'},
#  {'title': 'Clear Lake Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.clgms.org/',
#   'city': 'Houston'},
#  {'title': 'Cowtown Gem, Mineral & Glass Society',
#   'state': 'Texas',
#   'link': 'http://cera-fw.org/gem-mineral-glass/',
#   'city': 'Fort Worth'},
#  {'title': 'Dallas Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.dallasgemandmineral.org/',
#   'city': 'Dallas'},
#  {'title': 'Dallas Paleontological Society',
#   'state': 'Texas',
#   'link': 'https://dps.wildapricot.org/',
#   'city': 'Dallas'},
#  {'title': 'East Texas Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.etgms.com/',
#   'city': 'Tyler'},
#  {'title': 'El Paso Mineral and Gem Society, Inc.',
#   'state': 'Texas',
#   'link': 'http://www.epmgs.com/',
#   'city': 'El Paso'},
#  {'title': 'Fort Worth Gem and Mineral Club',
#   'state': 'Texas',
#   'link': 'http://www.fortworthgemandmineralclub.org/',
#   'city': 'Fort Worth'},
#  {'title': 'Fredericksburg Rockhounds',
#   'state': 'Texas',
#   'link': 'http://fredericksburgrockhounds.org/',
#   'city': 'Fredericksburg'},
#  {'title': 'Geological Society of San Antonio',
#   'state': 'Texas',
#   'link': 'http://www.geosa.org/',
#   'city': 'San Antonio'},
#  {'title': 'Golden Spread Gem, Mineral and Treasure Society',
#   'state': 'Texas',
#   'link': 'http://www.amarillotreasure.com/',
#   'city': 'Amarillo'},
#  {'title': 'Gulf Coast Gem & Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.gcgms.org/',
#   'city': 'Corpus Christi'},
#  {'title': 'Houston Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.hgms.org/',
#   'city': 'Houston'},
#  {'title': 'Lubbock Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.lubbockgemandmineral.org/',
#   'city': 'Lubbock'},
#  {'title': 'Midland Gem and Mineral Society, Inc.',
#   'state': 'Texas',
#   'link': 'https://www.facebook.com/midlandgemandmineral/',
#   'city': 'Midland'},
#  {'title': 'Oak Cliff Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.ocgemandmineral.com/',
#   'city': 'Dallas'},
#  {'title': 'Paleontological Society of Austin',
#   'state': 'Texas',
#   'link': 'http://www.austinpaleo.org/',
#   'city': 'Austin'},
#  {'title': 'Pine Country Gem & Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.pinecountry-gms.org/',
#   'city': 'Jasper'},
#  {'title': 'Piney Woods Gem & Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.pwgms.org/',
#   'city': 'Huntsville'},
#  {'title': 'Pleasant Oaks Gem & Mineral Club',
#   'state': 'Texas',
#   'link': 'http://www.pogmc.org/',
#   'city': 'Dallas'},
#  {'title': "Rollin' Rock Club, Inc.",
#   'state': 'Texas',
#   'link': 'https://sites.google.com/site/rollinrockclub/',
#   'city': "Rollin' Rock Club Of Texas And Any Other State Or Country Of The World and Outer Space"},
#  {'title': 'South Texas Geological Society',
#   'state': 'Texas',
#   'link': 'http://www.stgs.org/',
#   'city': 'San Antonio'},
#  {'title': 'Southwest Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.swgemandmineral.org/',
#   'city': 'San Antonio'},
#  {'title': 'Texas Faceters Guild',
#   'state': 'Texas',
#   'link': 'http://texasfacetersguild.org/',
#   'city': 'Houston'},
#  {'title': 'Tri-City Gem and Mineral Society, Inc.',
#   'state': 'Texas',
#   'link': 'https://www.facebook.com/midlandgemandmineral/',
#   'city': 'Temple'},
#  {'title': 'Waco Gem and Mineral Club',
#   'state': 'Texas',
#   'link': 'http://www.wacogemandmineral.org/',
#   'city': 'Waco'},
#  {'title': 'Williamson County Gem and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://www.wcgms.org/',
#   'city': 'Georgetown'},
#  {'title': 'Wise County Fossil, Rock and Mineral Society',
#   'state': 'Texas',
#   'link': 'http://wisecofossilrockandmineralsoc.weebly.com/',
#   'city': 'Decatur'},
#  {'title': 'Beehive Rock and Gem Club',
#   'state': 'Utah',
#   'link': 'http://www.beehiverockandgem.com/',
#   'city': 'Ogden'},
#  {'title': 'Cache Rock and Gem Club',
#   'state': 'Utah',
#   'link': 'http://cacherockgemclub.weebly.com/',
#   'city': 'Smithfield'},
#  {'title': 'Golden Spike Gem & Mineral Society',
#   'state': 'Utah',
#   'link': 'http://goldenspikegem.org/',
#   'city': 'Ogden'},
#  {'title': 'Mineral Collectors of Utah',
#   'state': 'Utah',
#   'link': 'http://m-c-u.org/',
#   'city': 'Salt Lake City'},
#  {'title': 'Moab Rock Club',
#   'state': 'Utah',
#   'link': 'https://www.facebook.com/Moab-Rock-Club-1508131859497762/',
#   'city': 'Moab'},
#  {'title': 'Rockhounders Outreach for Community Knowledge',
#   'state': 'Utah',
#   'link': 'http://www.rockhoundersock.com/',
#   'city': 'Sandy'},
#  {'title': 'Timpanogos Gem & Mineral Society',
#   'state': 'Utah',
#   'link': 'http://timprocks.weebly.com/',
#   'city': 'Provo'},
#  {'title': 'Tooele Gem & Mineral Society',
#   'state': 'Utah',
#   'link': 'https://www.facebook.com/Tooele-Gem-Mineral-Society-1742342656045404/',
#   'city': 'Tooele'},
#  {'title': 'Wasatch Gem Society',
#   'state': 'Utah',
#   'link': 'http://www.wasatchgemsociety.com/',
#   'city': 'Salt Lake City'},
#  {'title': 'Burlington Gem and Mineral Club',
#   'state': 'Vermont',
#   'link': 'http://www.burlingtongemandmineralclub.org/',
#   'city': 'Burlington'},
#  {'title': 'Rutland Rock & Mineral Club',
#   'state': 'Vermont',
#   'link': 'http://www.rutlandrockmineralclub.50webs.com/',
#   'city': 'Rutland'},
#  {'title': 'Gem and Mineral Hunters, Inc.',
#   'state': 'Virginia',
#   'link': 'http://www.gmhonline.org/',
#   'city': 'Manassas'},
#  {'title': 'Gem and Mineral Society of Lynchburg',
#   'state': 'Virginia',
#   'link': 'http://www.lynchburgrockclub.org/',
#   'city': 'Lynchburg'},
#  {'title': 'Gem and Mineral Society of the Virginia Peninsula',
#   'state': 'Virginia',
#   'link': 'http://www.gmsvp.org/',
#   'city': 'Hampton'},
#  {'title': 'Northern Virginia Mineral Club, Inc.',
#   'state': 'Virginia',
#   'link': 'http://www.novamineralclub.org/',
#   'city': 'Arlington'},
#  {'title': 'Richmond Gem & Mineral Society',
#   'state': 'Virginia',
#   'link': 'http://www.rgms-va.info/',
#   'city': 'Richmond'},
#  {'title': 'Roanoke Valley Mineral & Gem Society',
#   'state': 'Virginia',
#   'link': 'https://www.facebook.com/RVMGS/',
#   'city': 'Roanoke'},
#  {'title': 'Shenandoah Valley Gem & Mineral Society',
#   'state': 'Virginia',
#   'link': 'http://www.shenandoahvalleyrockclub.org/',
#   'city': 'Waynesboro'},
#  {'title': 'Tidewater Gem & Mineral Society',
#   'state': 'Virginia',
#   'link': 'http://tgms.weebly.com/',
#   'city': 'Virginia Beach'},
#  {'title': 'Bellevue Rock Club, Inc.',
#   'state': 'Washington',
#   'link': 'http://www.bellevuerockclub.org/',
#   'city': 'Bellevue'},
#  {'title': 'Cascade Mineralogical Society Inc',
#   'state': 'Washington',
#   'link': 'http://www.cascademineralogicalsociety.org/',
#   'city': 'Kent'},
#  {'title': 'Clallam County Gem & Mineral Association',
#   'state': 'Washington',
#   'link': 'http://www.olympicrocks.com/',
#   'city': 'Port Angeles'},
#  {'title': 'Darrington Rock & Gem Club',
#   'state': 'Washington',
#   'link': 'https://www.facebook.com/DarringtonRGC/',
#   'city': 'Darrington'},
#  {'title': 'East KingCo Rock Club',
#   'state': 'Washington',
#   'link': 'http://www.eastkingco.org/',
#   'city': 'Kirkland'},
#  {'title': 'Everett Rock & Gem Club',
#   'state': 'Washington',
#   'link': 'http://www.everettrockclub.com/',
#   'city': 'Everett'},
#  {'title': 'Ginkgo Mineral Society',
#   'state': 'Washington',
#   'link': 'http://wenatcheerockclub.org/',
#   'city': 'Wenatchee'},
#  {'title': 'Kitsap Mineral and Gem Societ',
#   'state': 'Washington',
#   'link': 'http://www.kmgs.org/',
#   'city': 'Bremerton'},
#  {'title': 'Lakeside Gem & Mineral Club, Inc.',
#   'state': 'Washington',
#   'link': 'http://www.lakesidegemandmineralclub.com/',
#   'city': 'Kennewick'},
#  {'title': 'Maplewood Rock & Gem Community Club',
#   'state': 'Washington',
#   'link': 'http://www.maplewoodrockclub.com/',
#   'city': 'Edmonds'},
#  {'title': 'Marcus Whitman Gem and Mineral Society',
#   'state': 'Washington',
#   'link': 'https://www.sites.google.com/site/mwgemandmineral/',
#   'city': 'Walla Walla'},
#  {'title': 'Marysville Rock & Gem Club, Inc.',
#   'state': 'Washington',
#   'link': 'https://sites.google.com/site/marysvillerockngemclub/',
#   'city': 'Marysville'},
#  {'title': 'Mount Baker Rock And Gem Club',
#   'state': 'Washington',
#   'link': 'http://mtbakerrockclub.org/',
#   'city': 'Bellingham'},
#  {'title': 'North American Miners Association',
#   'state': 'Washington',
#   'link': 'http://www.namaminers.org/',
#   'city': 'Kent'},
#  {'title': 'North Puget Sound Facetors Guild',
#   'state': 'Washington',
#   'link': 'http://www.facetguild.com/',
#   'city': 'Mount Vernon'},
#  {'title': 'Northwest Paleontological Association',
#   'state': 'Washington',
#   'link': 'http://nwpaleo.org/',
#   'city': 'Puget Sound'},
#  {'title': 'Panorama Gem & Mineral Club',
#   'state': 'Washington',
#   'link': 'http://panoramagem.com/',
#   'city': 'Arden'},
#  {'title': 'Puyallup Valley Gem & Mineral Club',
#   'state': 'Washington',
#   'link': 'https://www.facebook.com/PuyallupValleyGemClub',
#   'city': 'Puyallup'},
#  {'title': 'Skagit Rock and Gem Club',
#   'state': 'Washington',
#   'link': 'https://www.skagitrockandgem.com/',
#   'city': 'Mt. Vernon'},
#  {'title': 'Spokane Rock Rollers Club',
#   'state': 'Washington',
#   'link': 'http://www.rockrollers.org/WP/',
#   'city': 'Spokane Valley'},
#  {'title': 'North Seattle Lapidary & Mineral Club',
#   'state': 'Washington',
#   'link': 'http://www.northseattlerockclub.org',
#   'city': 'Seattle'},
#  {'title': 'Washington Agate and Mineral Society',
#   'state': 'Washington',
#   'link': 'https://wamsolympia.wordpress.com',
#   'city': 'Olympia'},
#  {'title': 'West Seattle Rock Club',
#   'state': 'Washington',
#   'link': 'http://www.westseattlerockclub.org/',
#   'city': 'Seattle'},
#  {'title': 'Yakima Rock & Mineral Club',
#   'state': 'Washington',
#   'link': 'http://www.yakimarockclub.com/',
#   'city': 'Yakima'},
#  {'title': 'Kanawha Rock and Gem Club',
#   'state': 'West Virginia',
#   'link': 'http://www.kanawharockandgemclub.org/',
#   'city': 'Charleston'},
#  {'title': 'Prehistoric West Virginia',
#   'state': 'West Virginia',
#   'link': 'http://prehistoricplanet.com/wv/',
#   'city': 'Morgantown'},
#  {'title': 'West Virginia Fossil Club Inc',
#   'state': 'West Virginia',
#   'link': 'http://www.westvirginiafossilclub.com/',
#   'city': 'Clarksburg'},
#  {'title': 'Badger Lapidary & Geological Society, Inc.',
#   'state': 'Wisconsin',
#   'link': 'http://www.badgerrockclub.org/',
#   'city': 'Monroe'},
#  {'title': 'Coulee Rock Club of La Crosse',
#   'state': 'Wisconsin',
#   'link': 'https://www.facebook.com/pages/The-Coulee-Rock-Club/182345351787782',
#   'city': 'La Crosse'},
#  {'title': 'Heart of Wisconsin Gem & Mineral Society',
#   'state': 'Wisconsin',
#   'link': 'https://www.heartofwisconsinrocks.com/',
#   'city': 'Marshfield & Stevens Point'},
#  {'title': 'Kettle Moraine Geological Society',
#   'state': 'Wisconsin',
#   'link': 'http://www.kmgsrocks.com/',
#   'city': 'Pewaukee'},
#  {'title': 'Lakeland Gem Club',
#   'state': 'Wisconsin',
#   'link': 'http://www.lakelandgemclub.com/',
#   'city': 'Minocqua'},
#  {'title': 'Madison Gem and Mineral Club',
#   'state': 'Wisconsin',
#   'link': 'http://www.madisonrockclub.org/',
#   'city': 'Madison'},
#  {'title': 'Northwest Wisconsin Gem & Mineral Society',
#   'state': 'Wisconsin',
#   'link': 'http://www.cameronamericanlegion.org/rockclub.html',
#   'city': 'Cameron'},
#  {'title': 'Oshkosh Earth Science Club',
#   'state': 'Wisconsin',
#   'link': 'https://sites.google.com/site/oshkoshearthscienceclub/home',
#   'city': 'Oshkosh'},
#  {'title': 'Racine Geological Society, Inc',
#   'state': 'Wisconsin',
#   'link': 'http://rgs-wi.tripod.com/',
#   'city': 'Racine'},
#  {'title': "Weis'n'Miners Geology Club",
#   'state': 'Wisconsin',
#   'link': 'http://www.weismuseum.org/geology-club.html',
#   'city': 'Menasha'},
#  {'title': 'Wisconsin Geological Society',
#   'state': 'Wisconsin',
#   'link': 'http://www.wisgeologicalsociety.com/',
#   'city': 'West Allis'},
#  {'title': 'Cody 59ers Rock Club',
#   'state': 'Wyoming',
#   'link': 'http://www.cody59ers.com/',
#   'city': 'Cody'},
#  {'title': 'Riverton Mineral and Gem Society',
#   'state': 'Wyoming',
#   'link': 'http://www.rivertonmgs.com/',
#   'city': 'Riverton'},
#  {'title': 'Wyoming State Mineral and Gem Society',
#   'state': 'Wyoming',
#   'link': 'http://wymineralandgemsociety.org',
#   'city': 'Cody'}]

# %%
#Creating dataframe rock_df from rock_list

rock_df = pd.DataFrame(rock_list)
rock_df.head(50)
# Out:
#                                                 title       state  \
# 0                  Alabama Mineral & Lapidary Society     Alabama
# 1                           Dothan Gem & Mineral Club     Alabama
# 2                  Huntsville Gem and Mineral Society     Alabama
# 3                           Mobile Rock & Gem Society     Alabama
# 4                    Montgomery Gem & Mineral Society     Alabama
# 5                       Chugach Gem & Mineral Society      Alaska
# 6                        Mat-Su Rock and Mineral Club      Alaska
# 7                   Apache Junction Rock and Gem Club     Arizona
# 8                         Black Canyon City Rock Club     Arizona
# 9                  Daisy Mountain Rock & Mineral Club     Arizona
# 10                  Gila County Gem & Mineral Society     Arizona
# 11                      Huachuca Mineral and Gem Club     Arizona
# 12                  Lake Havasu Gem & Mineral Society     Arizona
# 13                   Mineralogical Society of Arizona     Arizona
# 14                          Mingus Gem & Mineral Club     Arizona
# 15                           Mohave County Gemstoners     Arizona
# 16                           Old Pueblo Lapidary Club     Arizona
# 17                      Pinal Gem and Mineral Society     Arizona
# 18                        Prescott Gem & Mineral Club     Arizona
# 19          Quartzsite Roadrunners Gem & Mineral Club     Arizona
# 20                                    Rockhounds West     Arizona
# 21                          Sedona Gem & Mineral Club     Arizona
# 22                   Silvery Colorado River Rock Club     Arizona
# 23                      Sunsites Gem and Mineral Club     Arizona
# 24                     Tucson Gem and Mineral Society     Arizona
# 25                             Verde River Rockhounds     Arizona
# 26                    West Valley Rock & Mineral Club     Arizona
# 27                  White Mountain Gem & Mineral Club     Arizona
# 28                 Wickenburg Gem and Mineral Society     Arizona
# 29  Central Arkansas Gem, Mineral and Geology Society    Arkansas
# 30           Northwest Arkansas Gem & Mineral Society    Arkansas
# 31     Ozark Earth Science Gem, Mineral & Fossil Club    Arkansas
# 32                Amador County Gem & Mineral Society  California
# 33                              American Opal Society  California
# 34               Antelope Valley Gem and Mineral Club  California
# 35                              Antioch Lapidary Club  California
# 36                          Borrego Rock and Gem Club  California
# 37                    Calaveras Gem & Mineral Society  California
# 38              Carmel Valley Gem and Mineral Society  California
# 39         Central Coast Treasure Hunters Association  California
# 40                         Coalinga Rockhound Society  California
# 41                          Conejo Gem & Mineral Club  California
# 42                 Contra Costa Mineral & Gem Society  California
# 43              The Culver City Rock and Mineral Club  California
# 44                            Del Air Rockhounds Club  California
# 45                      Delvers Gem & Mineral Society  California
# 46              El Cajon Valley Gem & Mineral Society  California
# 47           El Dorado County Mineral and Gem Society  California
# 48              Faceters Guild of Southern California  California
# 49            Fallbrook Gem and Mineral Society, Inc.  California
#
#                                                  link               city
# 0                        http://www.lapidaryclub.com/         Birmingham
# 1                 http://www.wiregrassrockhounds.com/             Dothan
# 2                           http://huntsvillegms.org/         Huntsville
# 3                    http://www.mobilerockandgem.com/             Mobile
# 4     http://montgomerygemandmineralsociety.com/mgms/         Montgomery
# 5         http://www.chugachgemandmineralsociety.com/          Anchorage
# 6                           http://matsurockclub.com/             Palmer
# 7                          http://www.ajrockclub.com/    Apache Junction
# 8                  http://www.bccrockclub.mysite.com/  Black Canyon City
# 9                               http://www.dmrmc.com/             Anthem
# 10                                http://gilagem.org/              Miami
# 11         http://www.huachucamineralandgemclub.info/       Sierra Vista
# 12                      http://www.lakehavasugms.org/   Lake Havasu City
# 13                              http://www.msaaz.org/         Scottsdale
# 14                         http://www.mingusclub.org/         Cottonwood
# 15                         http://www.gemstoners.org/            Kingman
# 16                       http://www.lapidaryclub.org/             Tucson
# 17  https://www.pinalgeologymuseum.org/index.php/p...           Coolidge
# 18                 http://www.prescottgemmineral.org/    Prescott Valley
# 19                              http://www.qrgmc.org/         Quartzsite
# 20                    http://rockhounds.scwclubs.com/            Phoenix
# 21                http://www.sedonagemandmineral.org/             Sedona
# 22                         http://scrrc.blogspot.com/      Bullhead City
# 23   https://sites.google.com/site/cochisecountyrock/             Pearce
# 24                               http://www.tgms.org/             Tucson
# 25               http://www.verderiverrockhounds.com/         Cottonwood
# 26       http://www.westvalleyrockandmineralclub.com/            Buckeye
# 27               http://whitemountain-azrockclub.org/           Show Low
# 28                      http://www.wickenburggms.org/         Wickenburg
# 29                 http://www.centralarrockhound.org/        Little Rock
# 30                      http://www.nwarockhounds.org/     Siloam Springs
# 31                 https://www.ozarkearthscience.com/      Mountain Home
# 32                http://www.amadorgemandmineral.org/       Sutter Creek
# 33                        http://www.opalsociety.org/            Anaheim
# 34                           http://avgem.weebly.com/          Lancaster
# 35                http://www.antiochlapidaryclub.com/            Antioch
# 36                http://www.abdnha.org/bragclub.html    Borrego Springs
# 37             http://www.calaverasgemandmineral.org/        Angels Camp
# 38                            http://www.cvgms.rocks/      Pacific Grove
# 39                              http://www.cctha.org/    San Luis Obispo
# 40  https://sites.google.com/site/coalingarockhounds/           Coalinga
# 41                              http://www.cgamc.org/      Thousand Oaks
# 42                              http://www.ccmgs.org/            Concord
# 43                        http://culvercityrocks.org/        Culver City
# 44              http://delairrockhounds.blogspot.com/         Northridge
# 45              https://delversgemclub.wordpress.com/         Bellflower
# 46                             http://www.ecvgms.org/           El Cajon
# 47              http://www.eldoradomineralandgem.org/        Placerville
# 48                              http://www.fgosc.com/         Buena Park
# 49                 http://www.fgms.org/FGMS/Home.html          Fallbrook

# %%
#Creating .csv file from df

rock_df.to_csv(r'/Users/karthikanamboothiri/Desktop/Columbia_academics/CODE/Files/rocks-clubs.csv', index=False)
