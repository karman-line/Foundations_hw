# %%
import requests
url = "https://pokeapi.co/api/v2/pokemon/55/"
r = requests.get(url)

# %%
print(r.json())
# Out:
# {'abilities': [{'ability': {'name': 'damp', 'url': 'https://pokeapi.co/api/v2/ability/6/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'cloud-nine', 'url': 'https://pokeapi.co/api/v2/ability/13/'}, 'is_hidden': False, 'slot': 2}, {'ability': {'name': 'swift-swim', 'url': 'https://pokeapi.co/api/v2/ability/33/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 175, 'forms': [{'name': 'golduck', 'url': 'https://pokeapi.co/api/v2/pokemon-form/55/'}], 'game_indices': [{'game_index': 128, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 128, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 128, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 55, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 55, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 55, 'version': 
# ...

# %%
data = r.json()
print(data.keys())
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
print(data['name'])
# Out:
# golduck

# %%
r2 = requests.get("https://pokeapi.co/api/v2/type/electric/")

# %%
pok_type = r2.json()
print(pok_type.keys())
# Out:
# dict_keys(['damage_relations', 'game_indices', 'generation', 'id', 'move_damage_class', 'moves', 'name', 'names', 'pokemon'])

# %%
print(pok_type['names'])
# Out:
# [{'language': {'name': 'ja-Hrkt', 'url': 'https://pokeapi.co/api/v2/language/1/'}, 'name': 'でんき'}, {'language': {'name': 'ko', 'url': 'https://pokeapi.co/api/v2/language/3/'}, 'name': '전기'}, {'language': {'name': 'fr', 'url': 'https://pokeapi.co/api/v2/language/5/'}, 'name': 'Électrik'}, {'language': {'name': 'de', 'url': 'https://pokeapi.co/api/v2/language/6/'}, 'name': 'Elektro'}, {'language': {'name': 'es', 'url': 'https://pokeapi.co/api/v2/language/7/'}, 'name': 'Eléctrico'}, {'language': {'name': 'it', 'url': 'https://pokeapi.co/api/v2/language/8/'}, 'name': 'Elettro'}, {'language': {'name': 'en', 'url': 'https://pokeapi.co/api/v2/language/9/'}, 'name': 'Electric'}]

# %%
pok_electric = 0
for a in pok_type['pokemon']:
    print(a['pokemon']['name'])
    pok_electric = pok_electric+1
    
print(pok_electric)
# Out:
# pikachu
# raichu
# magnemite
# magneton
# voltorb
# electrode
# electabuzz
# jolteon
# zapdos
# chinchou
# lanturn
# pichu
# mareep
# flaaffy
# ampharos
# elekid
# raikou
# electrike
# manectric
# plusle
# minun
# shinx
# luxio
# luxray
# pachirisu
# magnezone
# electivire
# rotom
# blitzle
# zebstrika
# emolga
# joltik
# galvantula
# tynamo
# eelektrik
# eelektross
# stunfisk
# thundurus-incarnate
# zekrom
# helioptile
# heliolisk
# dedenne
# charjabug
# vikavolt
# togedemaru
# tapu-koko
# xurkitree
# zeraora
# yamper
# boltund
# toxel
# toxtricity
# pincurchin
# morpeko
# dracozolt
# arctozolt
# rotom-heat
# rotom-wash
# rotom-frost
# rotom-fan
# rotom-mow
# thundurus-therian
# ampharos-mega
# manectric-mega
# pikachu-rock-star
# pikachu-belle
# pikachu-pop-star
# pikachu-phd
# pikachu-libre
# pikachu-cosplay
# pikachu-original-cap
# pikachu-hoenn-cap
# pikachu-sinnoh-cap
# pikachu-unova-cap
# pikachu-kalos-cap
# pikachu-alola-cap
# raichu-alola
# geodude-alola
# graveler-alola
# ...

# %%
r3 = requests.get("https://pokeapi.co/api/v2/pokemon/eevee/")
eevee = r3.json()

# %%
print(eevee.keys())
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
print(eevee['stats'])
# Out:
# [{'base_stat': 55, 'effort': 0, 'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}, {'base_stat': 55, 'effort': 0, 'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}, {'base_stat': 50, 'effort': 0, 'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}, {'base_stat': 45, 'effort': 0, 'stat': {'name': 'special-attack', 'url': 'https://pokeapi.co/api/v2/stat/4/'}}, {'base_stat': 65, 'effort': 1, 'stat': {'name': 'special-defense', 'url': 'https://pokeapi.co/api/v2/stat/5/'}}, {'base_stat': 55, 'effort': 0, 'stat': {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}}]

# %%
r4 = requests.get("https://pokeapi.co/api/v2/pokemon/pikachu/")
pikachu = r4.json()
print(pikachu.keys())
# Out:
# dict_keys(['abilities', 'base_experience', 'forms', 'game_indices', 'height', 'held_items', 'id', 'is_default', 'location_area_encounters', 'moves', 'name', 'order', 'species', 'sprites', 'stats', 'types', 'weight'])

# %%
print(pikachu['stats'])
# Out:
# [{'base_stat': 35, 'effort': 0, 'stat': {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}}, {'base_stat': 55, 'effort': 0, 'stat': {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}}, {'base_stat': 40, 'effort': 0, 'stat': {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}}, {'base_stat': 50, 'effort': 0, 'stat': {'name': 'special-attack', 'url': 'https://pokeapi.co/api/v2/stat/4/'}}, {'base_stat': 50, 'effort': 0, 'stat': {'name': 'special-defense', 'url': 'https://pokeapi.co/api/v2/stat/5/'}}, {'base_stat': 90, 'effort': 2, 'stat': {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}}]

# %%
eev_speed=0
for i in eevee['stats']:
    print('..................')
    print(i['stat'])
    eev_speed = i['stat']
    
print(eev_speed['name'])
# Out:
# ..................
# {'name': 'hp', 'url': 'https://pokeapi.co/api/v2/stat/1/'}
# ..................
# {'name': 'attack', 'url': 'https://pokeapi.co/api/v2/stat/2/'}
# ..................
# {'name': 'defense', 'url': 'https://pokeapi.co/api/v2/stat/3/'}
# ..................
# {'name': 'special-attack', 'url': 'https://pokeapi.co/api/v2/stat/4/'}
# ..................
# {'name': 'special-defense', 'url': 'https://pokeapi.co/api/v2/stat/5/'}
# ..................
# {'name': 'speed', 'url': 'https://pokeapi.co/api/v2/stat/6/'}
# speed

# %%
w_r = requests.get("http://api.weatherapi.com/v1/current.json?key=766a280a9a8a44d8b5b43905200411&q=London")
curr_weather_data = w_r.json()

# %%
print(curr_weather_data)
# Out:
# {'location': {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1604464954, 'localtime': '2020-11-04 4:42'}, 'current': {'last_updated_epoch': 1604453409, 'last_updated': '2020-11-04 01:30', 'temp_c': 6.0, 'temp_f': 42.8, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 230, 'wind_dir': 'SW', 'pressure_mb': 1027.0, 'pressure_in': 30.8, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 81, 'cloud': 0, 'feelslike_c': 4.0, 'feelslike_f': 39.2, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 1.0, 'gust_mph': 6.9, 'gust_kph': 11.2}}

# %%
print(curr_weather_data.keys())
# Out:
# dict_keys(['location', 'current'])

# %%
print(curr_weather_data['location'])
# Out:
# {'name': 'London', 'region': 'City of London, Greater London', 'country': 'United Kingdom', 'lat': 51.52, 'lon': -0.11, 'tz_id': 'Europe/London', 'localtime_epoch': 1604464954, 'localtime': '2020-11-04 4:42'}

# %%
print(curr_weather_data['location']['region'])
# Out:
# City of London, Greater London

# %%
rl = 'http://api.bubblegum.com/gum/d0g/show.json?APIKEY=b335'
response = requests.get(rl)
data = response.json()
data.key()
print(type(data['flavors']))
for flavor in flavors:
    print(flavor)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Programs\Python\Python38\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...
